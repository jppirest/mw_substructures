# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
king8 = pd.read_csv('Clusters/haffner18.csv')

# %%
isocronas = pd.read_csv('jpt.csv')

# %%
isocrona = isocronas[isocronas['logAge'] == 7.2]
isocrona
# Out:
#         Zini       MH  logAge       Mini   int_IMF    Mass   logL   logTe  \
# 1981  0.0152  0.01508     7.2   0.090000  1.081690   0.090 -2.201  3.4004
# 1982  0.0152  0.01508     7.2   0.091649  1.097301   0.092 -2.190  3.4016
# 1983  0.0152  0.01508     7.2   0.100000  1.171106   0.100 -2.134  3.4075
# 1984  0.0152  0.01508     7.2   0.106745  1.225099   0.107 -2.093  3.4118
# 1985  0.0152  0.01508     7.2   0.120000  1.319316   0.120 -2.018  3.4197
# ...      ...      ...     ...        ...       ...     ...    ...     ...
# 2308  0.0152  0.01508     7.2  13.563140  2.628508  12.991  4.809  3.5504
# 2309  0.0152  0.01508     7.2  13.564510  2.628509  12.991  4.840  3.5467
# 2310  0.0152  0.01508     7.2  13.565977  2.628509  12.990  4.877  3.5423
# 2311  0.0152  0.01508     7.2  13.569751  2.628511  12.988  4.931  3.5361
# 2312  0.0152  0.01508     7.2  13.578246  2.628516  12.985  5.018  3.5262
#
#        logg  label  ...       Y        Xc        Xn        Xo  Cexcess  \
# ...

# %%
#isocrona = isocrona[isocrona['Gmag']<20]
plt.scatter(king8['BP-RP'],king8['Gmag'], zorder = 100)
Av = 1.52
E = Av/3.1
plt.plot(isocrona['G_BPmag']-isocrona['G_RPmag'] + E,isocrona['Gmag']+13.53 + Av, color ='k')
plt.gca().invert_yaxis()
