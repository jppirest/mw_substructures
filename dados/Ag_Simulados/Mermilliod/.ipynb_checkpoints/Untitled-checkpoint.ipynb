# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('vdb66.txt', sep = "\s+")
dados['V']
# Out:
# 0      18.71
# 1      19.79
# 2      19.41
# 3      19.07
# 4      20.50
#        ...
# 730    17.74
# 731    14.46
# 732    18.84
# 733    20.94
# 734    13.60
# Name: V, Length: 735, dtype: float64

# %%
plt.scatter(dados['B-V'], dados['V'])
plt.gca().invert_yaxis()

# %%
5*np.log10(
