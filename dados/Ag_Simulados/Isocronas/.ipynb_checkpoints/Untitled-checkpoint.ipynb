# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ag1 = [137.0,201.29,207.29, 213.5] #teorica, slope ag, slope iso, media
ag2 = 
labels = ['Teorica', 'Slope \n Aglomerado', 'Slope \n Isocrona', 'Media Slopes']

x = np.arange(len(labels))


fig, ax = plt.subplots()
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.bar(x,ag1)
# Out:
# <BarContainer object of 4 artists>

# %%
teoricas = [137.4,194.98,163.68]
slope_ag = [201.28,206.25,144.9]
slope_iso = [213.48,208.25,138.57]
mean = [207.3,207.54,141.7]


w = 0.1

x = ['Aglomerado 1', 'Aglomerado 2', 'Aglomerado 3']
bar1 = np.arange(len(x))
bar2 = [i+w for i in bar1]
bar3 = [i+w for i in bar2]
bar4 = [i+w for i in bar3]


fig, ax = plt.subplots(figsize=(10,8))
ax.bar(bar1,teoricas,0.1,label= 'Teórica')
ax.bar(bar2,slope_ag,0.1,label= 'Slope Aglomerado Simulado')
ax.bar(bar3,slope_iso,0.1,label= 'Slope Isócrona')
ax.bar(bar4,mean,0.1,label= 'Média dos Slopes')

ax.set_xticks([0.15,1.15,2.15])
ax.set_xticklabels(['Aglomerado 1','Aglomerado 2','Aglomerado 3'])
ax.set_ylabel('Distância (parsec)')
ax.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
din = [30,31,32,33,34]
vapo = [10,15,25,20,39]

w = 0.1
bar1 = np.arange(len(x))
bar2 = [i+w for i in bar1]
bar3 = [i+w for i in bar2]
bar4 = [i+w for i in bar3]

plt.figure(figsize=(10,8))
plt.bar(bar1,men_means,0.1,label= 'mens')
plt.bar(bar2,women_means,0.1,label= 'womens')
plt.bar(bar3,din,0.1,label= 'din')
plt.bar(bar4,vapo,0.1,label= 'vap')
plt.legend()
