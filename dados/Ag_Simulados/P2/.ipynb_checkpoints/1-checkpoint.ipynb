# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
isocronas = pd.read_csv('../../Isocronas/Regression_Iso.txt', header = 0)

# %%
from scipy.interpolate import interp1d

# %%
f1 = interp1d(isocronas['(B-V)TurnOff'],  isocronas['Age'],kind= 'linear')
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 


font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 13}

plt.rc('font', **font)

fig,ax = plt.subplots(figsize=(7,6)) #(figsize=(10,8))
plt.gca().invert_yaxis()



interpol_colour = np.linspace(isocronas['(B-V)TurnOff'].min(),isocronas['(B-V)TurnOff'].max(),100)
plt.plot(interpol_colour,f1(interpol_colour), color = 'k')
plt.scatter(isocronas['(B-V)TurnOff'], isocronas['Age'], c = isocronas['(B-V)TurnOff'],cmap = 'RdYlBu_r', zorder = 10)
plt.ylabel('log(Age)')
plt.xlabel(r'$(B-V)_o$' + ' Turnoff')
plt.title('Interpolação linear: cor do turnoff \n em função da idade')
# Out:
# Text(0.5, 1.0, 'Interpolação linear: cor do turnoff \n em função da idade')

# %%
#plt.scatter( isocronas['Age'], isocronas['(B-V)TurnOff'],   cmap = 'RdYlBu_r')

# %% [markdown]
# ## Aglomerado 1, E(B-V)=0.1

# %%
ag1 = pd.read_csv('../P1/LinearRegressAG1.txt', header = 0)
E=0.1
ag1.head()
# Out:
#       Slope   Intercept   Slope_Error   Intercept_Error  TurnOffColor
# 0  5.164931    6.893856      0.057215          0.047736      -0.157596

# %%
idade1 = f1(ag1['TurnOffColor ']-E)
idade1
# Out:
# array([7.0240387])

# %%
isocro1 = isocronas[isocronas['Age'] ==7.0]
isocro1
# Out:
#     Age     Slope  Intercept  Slope_Error  Intercept_Error   R_Value  \
# 45  7.0  6.443027   0.581311     0.067584           0.0336  0.999615
#
#     (B-V)TurnOff  MvTurnOff  Ajustadas/Total
# 45         -0.25      -2.74   0.140625= 9/64

# %%
## Método do Slope do Aglomerado
def distancia(a,b,b0,E):
    return 10**((a*E + (b-b0) - E*3.1 + 5 )/5)
d1 = distancia(ag1['Slope'].item(), ag1[' Intercept'].item(), isocro1['Intercept'].item(),E)
d1
# Out:
# 201.28331271475483

# %%
i1 = pd.read_csv('../P1/ag1.txt',header = 0)
i1.head()
# Out:
#         B-V          V
# 0  0.820441  10.900357
# 1 -0.033763   6.542515
# 2  1.692215  14.662077
# 3  0.803042  15.521706
# 4  0.559854   9.774405

# %%
iso = pd.read_csv('../../Isocronas/isocro.csv', header = 0)

idades = iso['log(Age)']
age = np.array([])
for element in idades:
    if element in age:
        continue
    elif element not in age:
        age = np.append(age,element)

iso1 = iso[iso['log(Age)']==7.0]

# %%
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 


font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 13}

plt.rc('font', **font)

fig,ax = plt.subplots(figsize=(7,5)) #(figsize=(10,8))
plt.gca().invert_yaxis()
plt.plot(iso1['(B-V)o'] + E,iso1['Mv'] +5*np.log10(d1/10)+3.1*E , label = 'Isócrona', color = 'black', zorder = 10)
plt.scatter(i1['B-V'] ,i1['V'], label = 'Aglomerado 1', color = 'none', edgecolor = 'darkviolet')
plt.legend(frameon=True)
plt.xlabel(r"$(B-V)$")
plt.ylabel(r"$V$")
# Out:
# Text(0, 0.5, '$V$')

# %%
modulodist = 5*np.log10(d1/10) + E*3.1
Xiso = iso1['(B-V)o'] + E
Yiso = iso1['Mv'] + modulodist 
Xaglo = i1['B-V'] 
Yaglo = i1['V']

dist_pontos = np.zeros_like(Xaglo)
distancias = []
for i in range(len(Xaglo)):
    pontos_aglo = np.array([Xaglo[i],Yaglo[i]])
    for x,y in zip(Xiso,Yiso):
        xy = np.array([x,y])
        distancias.append(np.linalg.norm(xy-pontos_aglo))
    dist_pontos[i] = min(distancias)

dist_pontos.mean(), modulodist
# Out:
# (0.021752983323533964, 6.82903885714809)

# %%
n_interacoes = 30
incremento = 0.05
medias = np.zeros((2,n_interacoes))
dist_loop = modulodist
for j in range(0,n_interacoes,1):
    Xiso = iso1['(B-V)o'] + E
    Yiso = iso1['Mv'] + dist_loop 
    Xaglo = i1['B-V'] 
    Yaglo = i1['V']
    dist_loop = dist_loop - incremento
    dist_pontos = np.zeros_like(Xaglo)
    distancias = []
    for i in range(len(Xaglo)):
        pontos_aglo = np.array([Xaglo[i],Yaglo[i]])
        for x,y in zip(Xiso,Yiso):
            xy = np.array([x,y])
            distancias.append(math.dist(xy,pontos_aglo))
        dist_pontos[i] = min(distancias)
    medias[0][j] = dist_pontos.mean()
    medias[1][j] = np.std(dist_pontos)

# %%
n_interacoes = 30
incremento = 0.05
medias = np.zeros((2,n_interacoes))
dist_loop = modulodist
X_i_a = np.zeros(len(Xaglo))
Y_i_a = np.zeros(len(Xaglo))

for j in range(0,n_interacoes,1):
    Xiso = iso1['(B-V)o'] + E
    Yiso = iso1['Mv'] + dist_loop 
    Xiso = Xiso.to_numpy()
    Yiso = Yiso.to_numpy()
    Xaglo = i1['B-V'] 
    Yaglo = i1['V']
    dist_loop = dist_loop - incremento
    dist_pontos = np.zeros_like(Xaglo)
    distancia=np.zeros((3,len(Xiso)))
    for i in range(len(Xaglo)):
        pontos_aglo = np.array([Xaglo[i],Yaglo[i]])
        for w in range(len(Xiso)):
            xy = np.array([Xiso[w],Yiso[w]])
            distancia[0][w] = math.dist(xy,pontos_aglo)
            distancia[1][w] = Xiso[w]
            distancia[2][w] = Yiso[w]
        dist_pontos[i] = min(distancia[0])
        localizacao = np.where(distancia[0]==min(distancia[0]))
        X_i_a[i] = distancia[1][localizacao]
        Y_i_a[i] = distancia[2][localizacao]
        
    medias[0][j] = dist_pontos.mean()
    medias[1][j] = np.std(dist_pontos)

# %%
local = np.where(medias[0]==min(medias[0]))
local
# Out:
# (array([9]),)

# %%
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 


font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 13}

plt.rc('font', **font)

fig,ax = plt.subplots(figsize=(10,8)) #(figsize=(10,8))
plt.gca().invert_yaxis()
plt.plot(iso1['(B-V)o'] + E,iso1['Mv'] + modulodist - incremento*local[0] , label = 'Isócrona Corrigida', color = 'black', zorder = 10)
plt.plot(iso1['(B-V)o'] + E,iso1['Mv'] + modulodist , '--', label = 'Isócrona Antiga', color = 'black', zorder = 10)
plt.scatter(i1['B-V'] ,i1['V'], label = 'Aglomerado 1', color = 'none', edgecolor = 'darkviolet')
plt.legend(frameon=True)
plt.xlabel(r"$(B-V)$")
plt.ylabel(r"$V$");

# %%
observado = 6 #V-Mv
modulodist = 5*np.log10(d1/10) + E*3.1

observado, modulodist - incremento*local[0]
# Out:
# (6, array([6.37903886]))

# %%
np.where(medias[0]==medias[0].min()),np.where(medias[1]==medias[1].min())
# Out:
# ((array([9]),), (array([26]),))

# %%
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13) 


font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 13}

plt.rc('font', **font)

fig,ax = plt.subplots(figsize=(10,8)) #(figsize=(10,8))
plt.gca().invert_yaxis()
plt.plot(iso1['(B-V)o'] + E,iso1['Mv'] + modulodist - incremento*local[0] , label = 'Isócrona Corrigida', color = 'black', zorder = 10)
plt.plot(iso1['(B-V)o'] + E,iso1['Mv'] + modulodist , '--', label = 'Isócrona Antiga', color = 'black', zorder = 10)
plt.plot(iso1['(B-V)o'] + E,iso1['Mv'] + modulodist - incremento*17 , label = '17', color = 'green', zorder = 10)
plt.plot(iso1['(B-V)o'] + E,iso1['Mv'] + modulodist - incremento*25 , label = 'Isocrona DESVIO PADRAO', color = 'red', zorder = 10)
plt.plot(iso1['(B-V)o'] + E,iso1['Mv'] + observado , '--', label = 'Observada', color = 'blue', zorder = 10)
plt.scatter(i1['B-V'] ,i1['V'], label = 'Aglomerado 1', color = 'none', edgecolor = 'darkviolet')
plt.legend(frameon=True)
plt.xlabel(r"$(B-V)$")
plt.ylabel(r"$V$");

# %%
import scipy.stats as stats
stats.chisquare(f_obs= Xaglo, f_exp = X_i_a)
# Out:
# Power_divergenceResult(statistic=7.502841410338235, pvalue=1.0)

# %%
stats.chisquare(f_obs= Yaglo, f_exp = Y_i_a)
# Out:
# Power_divergenceResult(statistic=1.4295501453014374, pvalue=1.0)
