# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
isocronas_geral = pd.read_csv('../../../Isocronas_Gaia/gaia_metal.csv')
isocronas_geral = isocronas_geral[isocronas_geral.label <= 4]
isocronas_geral['BP_RP'] = isocronas_geral['G_BPmag'] - isocronas_geral['G_RPmag']

# %%
aglomerado = pd.read_csv('membros/raio_phasespace.csv')

# %%
plt.scatter(aglomerado.bp_rp, aglomerado.phot_g_mean_mag)
plt.gca().invert_yaxis()

# %%
binarias = pd.read_csv('membros/not_binaray.csv')

plt.scatter(binarias.bp_rp, binarias.phot_g_mean_mag)
plt.scatter(iso.BP_RP +  (1.08337 - 0.63439)*0.05 , iso.Gmag + 12.2 + 0.83627*0.135)
plt.gca().invert_yaxis()

# %%
iso = isocronas_geral[(isocronas_geral.logAge == 9.2) & (isocronas_geral.MH == 0.2) ]
