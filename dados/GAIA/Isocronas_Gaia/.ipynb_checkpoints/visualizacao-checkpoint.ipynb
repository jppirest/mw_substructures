# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dados = pd.read_csv('teste.csv')

# %%
dados
# Out:
#          Zini       MH    logAge      Mini   int_IMF   Mass   logL   logTe  \
# 0      0.0152  0.01508   6.60000  0.090000  1.081690  0.090 -1.674  3.4146
# 1      0.0152  0.01508   6.60000  0.090446  1.085948  0.090 -1.672  3.4147
# 2      0.0152  0.01508   6.60000  0.104545  1.207988  0.105 -1.617  3.4202
# 3      0.0152  0.01508   6.60000  0.112700  1.269209  0.113 -1.583  3.4236
# 4      0.0152  0.01508   6.60000  0.120294  1.321247  0.120 -1.566  3.4252
# ...       ...      ...       ...       ...       ...    ...    ...     ...
# 14432  0.0152  0.01508  10.10001  0.974058  2.467318  0.691  3.283  3.4895
# 14433  0.0152  0.01508  10.10001  0.974058  2.467319  0.685  3.324  3.4831
# 14434  0.0152  0.01508  10.10001  0.974059  2.467319  0.675  3.362  3.4772
# 14435  0.0152  0.01508  10.10001  0.974059  2.467319  0.661  3.388  3.4738
# 14436  0.0152  0.01508  10.10001  0.990391  2.470882  0.523 -9.999  4.2223
#
# ...
