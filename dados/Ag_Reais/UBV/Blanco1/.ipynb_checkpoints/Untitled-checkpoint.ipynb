# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.odr import *

# %%
data = pd.read_csv('blanco1.fit',comment = '#', skiprows = 1, skipfooter = 1, header = None, usecols = [0,1], names = ['V','B-V'], delim_whitespace = True, engine = 'python')
data.head()
# Out:
# /home/jpt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#        V    B-V
# 0  13.48  0.940
# 1  11.69  0.745
# 2  10.96  0.570
# 3  13.15  0.830
# 4  12.16  0.820

# %%
from scipy.stats import linregress

y = data['V']
x = data['B-V']

linregress(x,y)
# Out:
# LinregressResult(slope=nan, intercept=nan, rvalue=nan, pvalue=nan, stderr=nan, intercept_stderr=nan)

# %%
y
# Out:
# 0      13.48
# 1      11.69
# 2      10.96
# 3      13.15
# 4      12.16
#        ...
# 206    11.42
# 207    12.12
# 208    15.65
# 209    15.51
# 210      NaN
# Name: V, Length: 211, dtype: float64
