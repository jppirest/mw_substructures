# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('ngc2287.csv')
x = df['BP-RP']
y = df['Gmag']

# %%
plt.scatter(x,y)
plt.gca().invert_yaxis()

# %%
regressoes = pd.read_csv('../Regressoes_Isocronas_Gaia.txt')
plt.scatter(regressoes['Age'],regressoes['(BP-RP)TurnOff'])
plt.gca().invert_yaxis()

# %%
hm = np.linspace(np.min(regressoes['(BP-RP)TurnOff']),np.max(regressoes['(BP-RP)TurnOff']), 36)
n = hm[2]-hm[1]
n
# Out:
# 0.04019999999999996

# %%
(-np.min(regressoes['(BP-RP)TurnOff']) + np.max(regressoes['(BP-RP)TurnOff']))/35
# Out:
# 0.040199999999999986

# %%
n = 0.04
n_bins = len(np.arange(np.min(regressoes['(BP-RP)TurnOff']),np.max(regressoes['(BP-RP)TurnOff']), n))
cor = 'forestgreen'

fig, ax = plt.subplots()
cor = 'forestgreen'
m, bins, patches = ax.hist(x,n_bins, ec = 'k',color = cor)

# %%
# Out:
# 16.25
